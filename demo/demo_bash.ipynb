# %% [markdown]
# # `Hallmark` Command Line Demo
#
# This Jupyter notebook demonstrates how `hallmark` is used in a command line.
#
# Because all cells are shell command, it is much more natural to use a `bash` kernel.
# To install a `bash` kernel to your Jupyter/python (virtual) environment, run
# ```bash
# pip install bash_kernel
# python -m bash_kernel.install
# ```

# %% [markdown]
# ## Remove Old Demo Repositories
#
# First, let's remove all old demo repositories.

# %%
rm -rf repo*

# %% [markdown]
# ## Initialize a Standard (Non-Bare) `Hallmark` Repository
#
# `Hallmark`'s commandline syntax is similar to `git`.
# To create an empty (standard) `hallmark` repository, we run `hallmark init [REPO]`.

# %%
hallmark init repo1

# %% [markdown]
# Check the content of the hallmark repository.
# It contains a ".hm" directory, which is itself a git repository.

# %%
ls -a repo1 repo1/.hm
# Out:
# repo1:
# .	..	.hm
#
# repo1/.hm:
# .		.git		data.tsv	README.md
# ..		config.yml	meta.yml

# %% [markdown]
# We can `cd` into the ".hm" directory and then run `git`.
# However, because `cd` is not a very good practice in Jupyter notebook,
# we will use `pushd` and `popd` instead.

# %%
pushd repo1/.hm && git status && popd
# Out:
# ~/astro_se_int/hallmark/demo/repo1/.hm ~/astro_se_int/hallmark/demo
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   config.yml
# 	new file:   data.tsv
# 	new file:   meta.yml
#
# ~/astro_se_int/hallmark/demo

# %% [markdown]
# Note, similar to `git init`, `hallmark init` does not commit your files.

# %% [markdown]
# ## Initialize a Bare Hallmark Repository
#
# Next, we will initialize a bare repository.
# Unlikely `git`, all we need is to explicitly postfix ".hm" to the repository name.

# %%
hallmark init repo2.hm

# %% [markdown]
# `repo2.hm` is itself a `git` repository.

# %%
ls -a repo2.hm
# Out:
# .		.git		data.tsv	README.md
# ..		config.yml	meta.yml

# %%
pushd repo2.hm && git status && popd
# Out:
# ~/astro_se_int/hallmark/demo/repo2.hm ~/astro_se_int/hallmark/demo
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   config.yml
# 	new file:   data.tsv
# 	new file:   meta.yml
#
# ~/astro_se_int/hallmark/demo

# %% [markdown]
# ## Add Files According to Python Format String

# %%
pushd repo1 && touch a{0,0.75,0.94}_i{0..180..30}.h5 && popd
ls repo1
# Out:
# ~/astro_se_int/hallmark/demo/repo1 ~/astro_se_int/hallmark/demo
# ~/astro_se_int/hallmark/demo
# a0_i{0..180..30}.h5	a0.75_i{0..180..30}.h5	a0.94_i{0..180..30}.h5

# %%
pushd repo1 && hallmark add "a{a}_i{i}.h5" && popd
# Out:
# ~/astro_se_int/hallmark/demo/repo1 ~/astro_se_int/hallmark/demo
# Failed to parse "/Users/nayera/astro_se_int/hallmark/demo/repo1/a0.75_i{0..180..30}.h5"
# Failed to parse "/Users/nayera/astro_se_int/hallmark/demo/repo1/a0.94_i{0..180..30}.h5"
# Failed to parse "/Users/nayera/astro_se_int/hallmark/demo/repo1/a0_i{0..180..30}.h5"
# No files matched the format string.
# ~/astro_se_int/hallmark/demo

# %%
pushd repo1 && hallmark commit -m  "Commit test" && popd
# Out:
# ~/astro_se_int/hallmark/demo/repo1 ~/astro_se_int/hallmark/demo
# Committed staged state changes.
# ~/astro_se_int/hallmark/demo

# %%
hallmark clone https://github.com/l6a/hallmark-demo-repo.hm.git repo3
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/astro_se_int/bin/hallmark", line 7, in <module>
#     sys.exit(hallmark())
#              ~~~~~~~~^^
#   File "/opt/anaconda3/envs/astro_se_int/lib/python3.13/site-packages/click/core.py", line 1485, in __call__
#     return self.main(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/astro_se_int/lib/python3.13/site-packages/click/core.py", line 1406, in main
#     rv = self.invoke(ctx)
#   File "/opt/anaconda3/envs/astro_se_int/lib/python3.13/site-packages/click/core.py", line 1873, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "/opt/anaconda3/envs/astro_se_int/lib/python3.13/site-packages/click/core.py", line 1269, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
